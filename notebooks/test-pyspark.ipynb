# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("First Spark application") \
    .getOrCreate()
# Out:
# 26/01/28 18:46:54 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
data = [
    {"userId": 1, "paymentAmount": 100.0, "date": "2026-01-01"},
    {"userId": 2, "paymentAmount": 150.0, "date": "2026-01-02"},
    {"userId": 3, "paymentAmount": 200.75, "date": "2026-01-03"},
    {"userId": 2, "paymentAmount": 50.25, "date": "2026-01-04"},
    {"userId": 1, "paymentAmount": 80.0, "date": "2026-01-05"}
]

df = spark.createDataFrame(data)

# %%
df.show()
# Out:
# +----------+-------------+------+
# |      date|paymentAmount|userId|
# +----------+-------------+------+
# |2026-01-01|        100.0|     1|
# |2026-01-02|        150.0|     2|
# |2026-01-03|       200.75|     3|
# |2026-01-04|        50.25|     2|
# |2026-01-05|         80.0|     1|
# +----------+-------------+------+

# %%
df.count()
# Out:
# 5
